# %%
import urllib.request as ur # import para obtener la página web 
import re                   # import para utilizar expresiones regulares 

# Obtener página web con incidencias de Madrid 
f = ur.urlopen('http://infocar.dgt.es/etraffic/Incidencias?ca=13&provIci=&caracter=acontecimiento&accion_consultar=Consultar&IncidenciasRETENCION=IncidenciasRETENCION&IncidenciasPUERTOS=IncidenciasPUERTOS&IncidenciasMETEOROLOGICA=IncidenciasMETEOROLOGICA&IncidenciasEVENTOS=IncidenciasEVENTOS&IncidenciasOTROS=IncidenciasOTROS&IncidenciasRESTRICCIONES=IncidenciasRESTRICCIONES&ordenacion=fechahora_ini-DESC')
s = f.read().decode()
f.close()

# %%
# Método para eliminar tags html que no nos interesan con ER 
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr,'',raw_html)
    return cleantext

# %%
from pprint import pprint     # import para hacer prints boninitos 

dividedByTr = s.split("<tr") # Dividir el string por tr para incidencias con hora fin 
endTimeElements = [] # Almacenará elementos que tienen hora fin 

# Obtener las incidencias que tienen hora fin 
print("Incidencias con hora fin")
endTime = re.compile(".*?<td.*?class='orange'>(\d\d:\d\d).*?(\d\d/\d\d/\d\d\d\d).*?<td.*?(\d\d:\d\d).*?(\d\d/\d\d/\d\d\d\d).*?<td.*?<td.*?<td.*?<b>(.*?)</b>.*?<td.*?<span.*?<b>(.*?)</b></span>.*?</td>.*?tr>",re.DOTALL)
for x in dividedByTr:
    confin = endTime.findall(x)
    #confin = re.findall(".*?<td.*?class='orange'>(\d\d:\d\d).*?(\d\d/\d\d/\d\d\d\d).*?<td.*?(\d\d:\d\d).*?(\d\d/\d\d/\d\d\d\d).*?<td.*?<td.*?<td.*?<b>(.*?)</b>.*?<td.*?<span.*?<b>(.*?)</b></span>.*?</td>.*?tr>",x,re.DOTALL)
    if len(confin): # Si el elemento contiene algún dato se agrega a la lista de elementos con hora fin
        endTimeElements.append(confin[0]) 
        pprint(confin)

# Obtener todas las incidencias 
print("\nTodas las incidencias") # Las cuales incluyen las que tienen hora fin pero no incluyen ese dato
conjunto = re.findall("<tr.*?<td.*?class='orange'>(\d\d:\d\d).*?(\d\d/\d\d/\d\d\d\d).*?<td.*?(\d\d:\d\d)?.*?(\d\d/\d\d/\d\d\d\d)?.*?<td.*?<td.*?<td.*?<b>(.*?)</b>.*?<td.*?<span.*?<b>(.*?)</b></span>.*?</td>.*?",s,re.DOTALL)
pprint(conjunto)
# Out:
# Incidencias con hora fin
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-50',
#   'RESTRICCIONES A MERCANCÍAS PELIGROSAS</b> por <b>CIRCULACIÓN</b> en<b> '
#   'Túneles Boadilla - Valdepastores</b>: </span> <span style="margin-top:10px; '
#   'float:left; clear:both">  -  La carretera  <b> <span '
#   'style="color:#ab3000">M-50 </span> </b> a la altura de <b>BOADILLA DEL '
#   'MONTE (MADRID)</b> desde el <b> km 77.7</b> al <b> km 72.7</b> sentido '
#   '<b>DECRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Decreciente')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-506',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Acceso a Madrid M-506</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-506 </span> </b> desde el <b> km 0 </b> en '
#   '<b>VILLAVICIOSA DE ODON (MADRID)</b> al <b> km 53</b> en <b>ARGANDA '
#   '(MADRID)</b> sentido <b>AMBOS SENTIDOS')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-45',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Acceso a Madrid M-45</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-45 </span> </b> desde el <b> km 0 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 31</b> en <b>SAN FERNANDO DE HENARES '
#   '(MADRID)</b> sentido <b>AMBOS SENTIDOS')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'A-42',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-42</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-42 </span> </b> a la altura de <b>MADRID '
#   '(MADRID)</b> desde el <b> km 6.2</b> al <b> km 27.5</b> sentido '
#   '<b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-40',
#   'RESTRICCIONES A MERCANCÍAS PELIGROSAS</b> por <b>CIRCULACIÓN</b> en<b> De '
#   'A-2 a A-42</b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  -  La carretera  <b> <span style="color:#ab3000">M-40 </span> '
#   '</b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 9</b> al <b> km '
#   '25</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Creciente')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-40',
#   'RESTRICCIONES A MERCANCÍAS PELIGROSAS</b> por <b>CIRCULACIÓN</b> en<b> '
#   'Túneles del Pardo</b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  -  La carretera  <b> <span style="color:#ab3000">M-40 </span> '
#   '</b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 57</b> al <b> km '
#   '46</b> sentido <b>DECRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Decreciente')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'A-3',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-3</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-3 </span> </b> desde el <b> km 7 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 40</b> en <b>PERALES DE TAJUÑA '
#   '(MADRID)</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida '
#   'Madrid')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'A-1',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida Madrid A-1</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-1 </span> </b> desde el <b> km 11.8 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 50</b> en <b>VENTURADA (MADRID)</b> '
#   'sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-40',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Acceso a Madrid M-40</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-40 </span> </b> a la altura de <b>MADRID '
#   '(MADRID)</b> desde el <b> km 0</b> al <b> km 61.3</b> sentido <b>AMBOS '
#   'SENTIDOS')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-50',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Acceso a Madrid M-50</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-50 </span> </b> desde el <b> km 0 </b> en '
#   '<b>SAN SEBASTIAN DE LOS REYES (MADRID)</b> al <b> km 84.5</b> en <b>ROZAS '
#   'DE MADRID (LAS) (MADRID)</b> sentido <b>AMBOS SENTIDOS')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-607',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid M-607</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-607 </span> </b> desde el <b> km 9.2 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 39.4</b> en <b>COLMENAR VIEJO (MADRID)</b> '
#   'sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-501',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid M-501</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-501 </span> </b> desde el <b> km 0 </b> en '
#   '<b>BOADILLA DEL MONTE (MADRID)</b> al <b> km 21.7</b> en <b>BRUNETE '
#   '(MADRID)</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida '
#   'Madrid')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'A-5',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-5</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-5 </span> </b> desde el <b> km 11.2 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 35</b> en <b>NAVALCARNERO (MADRID)</b> '
#   'sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'A-2',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-2</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-2 </span> </b> desde el <b> km 10.8 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 38</b> en <b>MECO (MADRID)</b> sentido '
#   '<b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'M-505',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid M-505</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-505 </span> </b> desde el <b> km 0 </b> en '
#   '<b>ROZAS DE MADRID (LAS) (MADRID)</b> al <b> km 29.5</b> en <b>ESCORIAL '
#   '(EL) (MADRID)</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia '
#   '<b>Salida Madrid')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'A-6',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-6</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-6 </span> </b> desde el <b> km 6.8 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 39.5</b> en <b>COLLADO VILLALBA '
#   '(MADRID)</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida '
#   'Madrid')]
# [('18:00',
#   '06/03/2019',
#   '21:00',
#   '06/03/2019',
#   'A-4',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-4</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-4 </span> </b> desde el <b> km 6.7 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 30</b> en <b>VALDEMORO (MADRID)</b> '
#   'sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid')]
# [('06:00',
#   '06/03/2019',
#   '23:00',
#   '06/03/2019',
#   'M-111',
#   'RESTRICCIONES A MERCANCÍAS PELIGROSAS</b> por <b>CIRCULACIÓN</b> en<b> '
#   'Túnel Barajas</b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  -  La carretera  <b> <span style="color:#ab3000">M-111 '
#   '</span> </b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 1.1</b> '
#   'al <b> km 5</b> sentido <b>AMBOS SENTIDOS')]
#
# Todas las incidencias
# [('18:48',
#   '06/03/2019',
#   '',
#   '',
#   'M-40',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>ACCIDENTE</b> y <b>CIRCULACIÓN</b> con '
#   'circulación irregular  en<b></b>: </span> <span style="margin-top:10px; '
#   'float:left; clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span '
#   'style="color:#ab3000">M-40 </span> </b> a la altura de <b>MADRID '
#   '(MADRID)</b> desde el <b> km 5</b> al <b> km 8</b> sentido <b>DECRECIENTE '
#   'DE LA KILOMETRACIÓN</b> hacia <b>A-6'),
#  ('18:48',
#   '06/03/2019',
#   '',
#   '',
#   'A-42',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span style="color:#ab3000">A-42 '
#   '</span> </b> a la altura de <b>GETAFE (MADRID)</b> desde el <b> km 12</b> '
#   'al <b> km 16</b> sentido <b>DECRECIENTE DE LA KILOMETRACIÓN</b> hacia '
#   '<b>MADRID'),
#  ('18:14',
#   '06/03/2019',
#   '',
#   '',
#   'A-6',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span style="color:#ab3000">A-6 '
#   '</span> </b> a la altura de <b>ROZAS DE MADRID (LAS) (MADRID)</b> desde el '
#   '<b> km 17</b> al <b> km 12</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> '
#   'hacia <b>COLLADO VILLALBA'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-50',
#   'RESTRICCIONES A MERCANCÍAS PELIGROSAS</b> por <b>CIRCULACIÓN</b> en<b> '
#   'Túneles Boadilla - Valdepastores</b>: </span> <span style="margin-top:10px; '
#   'float:left; clear:both">  -  La carretera  <b> <span '
#   'style="color:#ab3000">M-50 </span> </b> a la altura de <b>BOADILLA DEL '
#   'MONTE (MADRID)</b> desde el <b> km 77.7</b> al <b> km 72.7</b> sentido '
#   '<b>DECRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Decreciente'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-506',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Acceso a Madrid M-506</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-506 </span> </b> desde el <b> km 0 </b> en '
#   '<b>VILLAVICIOSA DE ODON (MADRID)</b> al <b> km 53</b> en <b>ARGANDA '
#   '(MADRID)</b> sentido <b>AMBOS SENTIDOS'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-45',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Acceso a Madrid M-45</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-45 </span> </b> desde el <b> km 0 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 31</b> en <b>SAN FERNANDO DE HENARES '
#   '(MADRID)</b> sentido <b>AMBOS SENTIDOS'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'A-42',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-42</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-42 </span> </b> a la altura de <b>MADRID '
#   '(MADRID)</b> desde el <b> km 6.2</b> al <b> km 27.5</b> sentido '
#   '<b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-40',
#   'RESTRICCIONES A MERCANCÍAS PELIGROSAS</b> por <b>CIRCULACIÓN</b> en<b> De '
#   'A-2 a A-42</b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  -  La carretera  <b> <span style="color:#ab3000">M-40 </span> '
#   '</b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 9</b> al <b> km '
#   '25</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Creciente'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-40',
#   'RESTRICCIONES A MERCANCÍAS PELIGROSAS</b> por <b>CIRCULACIÓN</b> en<b> '
#   'Túneles del Pardo</b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  -  La carretera  <b> <span style="color:#ab3000">M-40 </span> '
#   '</b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 57</b> al <b> km '
#   '46</b> sentido <b>DECRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Decreciente'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'A-3',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-3</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-3 </span> </b> desde el <b> km 7 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 40</b> en <b>PERALES DE TAJUÑA '
#   '(MADRID)</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida '
#   'Madrid'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'A-1',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida Madrid A-1</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-1 </span> </b> desde el <b> km 11.8 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 50</b> en <b>VENTURADA (MADRID)</b> '
#   'sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-40',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Acceso a Madrid M-40</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-40 </span> </b> a la altura de <b>MADRID '
#   '(MADRID)</b> desde el <b> km 0</b> al <b> km 61.3</b> sentido <b>AMBOS '
#   'SENTIDOS'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-50',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Acceso a Madrid M-50</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-50 </span> </b> desde el <b> km 0 </b> en '
#   '<b>SAN SEBASTIAN DE LOS REYES (MADRID)</b> al <b> km 84.5</b> en <b>ROZAS '
#   'DE MADRID (LAS) (MADRID)</b> sentido <b>AMBOS SENTIDOS'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-607',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid M-607</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-607 </span> </b> desde el <b> km 9.2 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 39.4</b> en <b>COLMENAR VIEJO (MADRID)</b> '
#   'sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-501',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid M-501</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-501 </span> </b> desde el <b> km 0 </b> en '
#   '<b>BOADILLA DEL MONTE (MADRID)</b> al <b> km 21.7</b> en <b>BRUNETE '
#   '(MADRID)</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida '
#   'Madrid'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'A-5',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-5</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-5 </span> </b> desde el <b> km 11.2 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 35</b> en <b>NAVALCARNERO (MADRID)</b> '
#   'sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'A-2',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-2</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-2 </span> </b> desde el <b> km 10.8 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 38</b> en <b>MECO (MADRID)</b> sentido '
#   '<b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-505',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid M-505</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">M-505 </span> </b> desde el <b> km 0 </b> en '
#   '<b>ROZAS DE MADRID (LAS) (MADRID)</b> al <b> km 29.5</b> en <b>ESCORIAL '
#   '(EL) (MADRID)</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia '
#   '<b>Salida Madrid'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'A-6',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-6</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-6 </span> </b> desde el <b> km 6.8 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 39.5</b> en <b>COLLADO VILLALBA '
#   '(MADRID)</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida '
#   'Madrid'),
#  ('18:00',
#   '06/03/2019',
#   '',
#   '',
#   'A-4',
#   'RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA</b> por '
#   '<b>CIRCULACIÓN</b> en<b> Salida de Madrid A-4</b>: </span> <span '
#   'style="margin-top:10px; float:left; clear:both">  -  La carretera  <b> '
#   '<span style="color:#ab3000">A-4 </span> </b> desde el <b> km 6.7 </b> en '
#   '<b>MADRID (MADRID)</b> al <b> km 30</b> en <b>VALDEMORO (MADRID)</b> '
#   'sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>Salida Madrid'),
#  ('17:53',
#   '06/03/2019',
#   '',
#   '',
#   'M-40',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span style="color:#ab3000">M-40 '
#   '</span> </b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 7</b> al '
#   '<b> km 3</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>A-3'),
#  ('17:28',
#   '06/03/2019',
#   '',
#   '',
#   'A-1',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span style="color:#ab3000">A-1 '
#   '</span> </b> a la altura de <b>ALCOBENDAS (MADRID)</b> desde el <b> km '
#   '16</b> al <b> km 14</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia '
#   '<b>SOMOSIERRA'),
#  ('17:27',
#   '06/03/2019',
#   '',
#   '',
#   'M-607',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span '
#   'style="color:#ab3000">M-607 </span> </b> a la altura de <b>TRES CANTOS '
#   '(MADRID)</b> desde el <b> km 14</b> al <b> km 16</b> sentido <b>DECRECIENTE '
#   'DE LA KILOMETRACIÓN</b> hacia <b>MADRID'),
#  ('17:27',
#   '06/03/2019',
#   '',
#   '',
#   'M-40',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span style="color:#ab3000">M-40 '
#   '</span> </b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 54</b> '
#   'al <b> km 59</b> sentido <b>DECRECIENTE DE LA KILOMETRACIÓN</b> hacia '
#   '<b>A-6'),
#  ('17:26',
#   '06/03/2019',
#   '',
#   '',
#   'A-6',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span style="color:#ab3000">A-6 '
#   '</span> </b> a la altura de <b>POZUELO DE ALARCON (MADRID)</b> desde el <b> '
#   'km 12.5</b> al <b> km 17</b> sentido <b>DECRECIENTE DE LA KILOMETRACIÓN</b> '
#   'hacia <b>MADRID'),
#  ('17:26',
#   '06/03/2019',
#   '',
#   '',
#   'M-40',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span style="color:#ab3000">M-40 '
#   '</span> </b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 46</b> '
#   'al <b> km 52</b> sentido <b>DECRECIENTE DE LA KILOMETRACIÓN</b> hacia '
#   '<b>A-6'),
#  ('17:25',
#   '06/03/2019',
#   '',
#   '',
#   'A-4',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span style="color:#ab3000">A-4 '
#   '</span> </b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 18</b> '
#   'al <b> km 17</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia '
#   '<b>CÓRDOBA'),
#  ('15:51',
#   '06/03/2019',
#   '',
#   '',
#   'M-40',
#   'RETENCIÓN / CONGESTIÓN</b> por <b>CIRCULACIÓN</b> con circulación '
#   'irregular  en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  - La AUTOPISTA / AUTOVÍA <b> <span style="color:#ab3000">M-40 '
#   '</span> </b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 12</b> '
#   'al <b> km 10</b> sentido <b>CRECIENTE DE LA KILOMETRACIÓN</b> hacia <b>A-3'),
#  ('06:00',
#   '06/03/2019',
#   '',
#   '',
#   'M-111',
#   'RESTRICCIONES A MERCANCÍAS PELIGROSAS</b> por <b>CIRCULACIÓN</b> en<b> '
#   'Túnel Barajas</b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  -  La carretera  <b> <span style="color:#ab3000">M-111 '
#   '</span> </b> a la altura de <b>MADRID (MADRID)</b> desde el <b> km 1.1</b> '
#   'al <b> km 5</b> sentido <b>AMBOS SENTIDOS'),
#  ('20:17',
#   '05/03/2019',
#   '',
#   '',
#   'AP-6',
#   'VIENTOS</b> en<b></b>: </span> <span style="margin-top:10px; float:left; '
#   'clear:both">  -  La carretera  <b> <span style="color:#ab3000">AP-6 </span> '
#   '</b> desde el <b> km 40 </b> en <b>ESTACION (LA) (MADRID)</b> al <b> km '
#   '110</b> en <b>ADANERO (ÁVILA)')]

# %%
diccionario = {} # variable que se utilizará para almacenar las incidencias una sola vez 

for x in range(len(endTimeElements)): # se ejecuta para cada elemento con hora fin 
    identificador = endTimeElements[x][0] + endTimeElements[x][1] + endTimeElements[x][4]  # concatenación de valores para crear identificador para diccionario
    diccionario.update({identificador : endTimeElements[x]}) # agregación de valores al diccionario

for x in range(len(conjunto)): # se ejecuta para cada elemento
    identificador = conjunto[x][0] + conjunto[x][1] + conjunto[x][4] # concatenación de valores para crear identificador para diccionario
    if diccionario.get(identificador) == None:    # En caso de que el identificador exista, salta este paso (es decir, el elemento tenía hora fin)
        diccionario.update({identificador : conjunto[x]}) # Si el identificador no existe, se crea un nuevo elemento en el diccionario
'''
Para todas las carreteras
Indica que hubo un atasco si la incidencia tiene hora fin 
Indica que existe un atasco si la incidencia no tiene hora fin 
'''
        
for x in diccionario:
    valores = diccionario.get(x) # obtener el valor correspondiente para el identificador 
    fin = "" # declarar variable para mensaje en caso de que la incidencia tenga hora fin
    cleantext =  cleanhtml(valores[5]) # quitar las etiquetas de html del texto que describe la incidencia 
    if valores[2] != '':  # En caso de que exista una hora fin
        mensaje = "Hubo un atasco en la carretera " + valores[4]
        fin = " el cual terminó a las " + valores[2] + " el día " + valores[3]
    else: 
        mensaje = "Existe un atasco en la carretera " + valores[4]
    mensaje = mensaje + " que inicio a las " + valores[0] + " el día " + valores[1]
    mensaje = mensaje + fin
    mensaje = mensaje + " con la siguientes características:\n" +  cleantext
    
    print(mensaje+"\n")
# Out:
# Hubo un atasco en la carretera M-50 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Acceso a Madrid M-50:    -  La carretera   M-50   desde el  km 0  en SAN SEBASTIAN DE LOS REYES (MADRID) al  km 84.5 en ROZAS DE MADRID (LAS) (MADRID) sentido AMBOS SENTIDOS
#
# Hubo un atasco en la carretera M-506 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Acceso a Madrid M-506:    -  La carretera   M-506   desde el  km 0  en VILLAVICIOSA DE ODON (MADRID) al  km 53 en ARGANDA (MADRID) sentido AMBOS SENTIDOS
#
# Hubo un atasco en la carretera M-45 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Acceso a Madrid M-45:    -  La carretera   M-45   desde el  km 0  en MADRID (MADRID) al  km 31 en SAN FERNANDO DE HENARES (MADRID) sentido AMBOS SENTIDOS
#
# Hubo un atasco en la carretera A-42 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida de Madrid A-42:    -  La carretera   A-42   a la altura de MADRID (MADRID) desde el  km 6.2 al  km 27.5 sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera M-40 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Acceso a Madrid M-40:    -  La carretera   M-40   a la altura de MADRID (MADRID) desde el  km 0 al  km 61.3 sentido AMBOS SENTIDOS
#
# Hubo un atasco en la carretera A-3 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida de Madrid A-3:    -  La carretera   A-3   desde el  km 7  en MADRID (MADRID) al  km 40 en PERALES DE TAJUÑA (MADRID) sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera A-1 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida Madrid A-1:    -  La carretera   A-1   desde el  km 11.8  en MADRID (MADRID) al  km 50 en VENTURADA (MADRID) sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera M-607 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida de Madrid M-607:    -  La carretera   M-607   desde el  km 9.2  en MADRID (MADRID) al  km 39.4 en COLMENAR VIEJO (MADRID) sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera M-501 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida de Madrid M-501:    -  La carretera   M-501   desde el  km 0  en BOADILLA DEL MONTE (MADRID) al  km 21.7 en BRUNETE (MADRID) sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera A-5 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida de Madrid A-5:    -  La carretera   A-5   desde el  km 11.2  en MADRID (MADRID) al  km 35 en NAVALCARNERO (MADRID) sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera A-2 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida de Madrid A-2:    -  La carretera   A-2   desde el  km 10.8  en MADRID (MADRID) al  km 38 en MECO (MADRID) sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera M-505 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida de Madrid M-505:    -  La carretera   M-505   desde el  km 0  en ROZAS DE MADRID (LAS) (MADRID) al  km 29.5 en ESCORIAL (EL) (MADRID) sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera A-6 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida de Madrid A-6:    -  La carretera   A-6   desde el  km 6.8  en MADRID (MADRID) al  km 39.5 en COLLADO VILLALBA (MADRID) sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera A-4 que inicio a las 18:00 el día 06/03/2019 el cual terminó a las 21:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A VEHÍCULOS QUE NECESITAN AUTORIZACIÓN COMPLEMENTARIA por CIRCULACIÓN en Salida de Madrid A-4:    -  La carretera   A-4   desde el  km 6.7  en MADRID (MADRID) al  km 30 en VALDEMORO (MADRID) sentido CRECIENTE DE LA KILOMETRACIÓN hacia Salida Madrid
#
# Hubo un atasco en la carretera M-111 que inicio a las 06:00 el día 06/03/2019 el cual terminó a las 23:00 el día 06/03/2019 con la siguientes características:
# RESTRICCIONES A MERCANCÍAS PELIGROSAS por CIRCULACIÓN en Túnel Barajas:    -  La carretera   M-111   a la altura de MADRID (MADRID) desde el  km 1.1 al  km 5 sentido AMBOS SENTIDOS
#
# Existe un atasco en la carretera M-40 que inicio a las 18:48 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por ACCIDENTE y CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  M-40   a la altura de MADRID (MADRID) desde el  km 5 al  km 8 sentido DECRECIENTE DE LA KILOMETRACIÓN hacia A-6
#
# Existe un atasco en la carretera A-42 que inicio a las 18:48 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  A-42   a la altura de GETAFE (MADRID) desde el  km 12 al  km 16 sentido DECRECIENTE DE LA KILOMETRACIÓN hacia MADRID
#
# Existe un atasco en la carretera A-6 que inicio a las 18:14 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  A-6   a la altura de ROZAS DE MADRID (LAS) (MADRID) desde el  km 17 al  km 12 sentido CRECIENTE DE LA KILOMETRACIÓN hacia COLLADO VILLALBA
#
# Existe un atasco en la carretera M-40 que inicio a las 17:53 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  M-40   a la altura de MADRID (MADRID) desde el  km 7 al  km 3 sentido CRECIENTE DE LA KILOMETRACIÓN hacia A-3
#
# Existe un atasco en la carretera A-1 que inicio a las 17:28 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  A-1   a la altura de ALCOBENDAS (MADRID) desde el  km 16 al  km 14 sentido CRECIENTE DE LA KILOMETRACIÓN hacia SOMOSIERRA
#
# Existe un atasco en la carretera M-607 que inicio a las 17:27 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  M-607   a la altura de TRES CANTOS (MADRID) desde el  km 14 al  km 16 sentido DECRECIENTE DE LA KILOMETRACIÓN hacia MADRID
#
# Existe un atasco en la carretera M-40 que inicio a las 17:27 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  M-40   a la altura de MADRID (MADRID) desde el  km 54 al  km 59 sentido DECRECIENTE DE LA KILOMETRACIÓN hacia A-6
#
# Existe un atasco en la carretera A-6 que inicio a las 17:26 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  A-6   a la altura de POZUELO DE ALARCON (MADRID) desde el  km 12.5 al  km 17 sentido DECRECIENTE DE LA KILOMETRACIÓN hacia MADRID
#
# Existe un atasco en la carretera M-40 que inicio a las 17:26 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  M-40   a la altura de MADRID (MADRID) desde el  km 46 al  km 52 sentido DECRECIENTE DE LA KILOMETRACIÓN hacia A-6
#
# Existe un atasco en la carretera A-4 que inicio a las 17:25 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  A-4   a la altura de MADRID (MADRID) desde el  km 18 al  km 17 sentido CRECIENTE DE LA KILOMETRACIÓN hacia CÓRDOBA
#
# Existe un atasco en la carretera M-40 que inicio a las 15:51 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  M-40   a la altura de MADRID (MADRID) desde el  km 12 al  km 10 sentido CRECIENTE DE LA KILOMETRACIÓN hacia A-3
#
# Existe un atasco en la carretera AP-6 que inicio a las 20:17 el día 05/03/2019 con la siguientes características:
# VIENTOS en:    -  La carretera   AP-6   desde el  km 40  en ESTACION (LA) (MADRID) al  km 110 en ADANERO (ÁVILA)

# %%
'''
Para la carretera M-40 
Indica que hubo un atasco si la incidencia tiene hora fin 
Indica que existe un atasco si la incidencia no tiene hora fin 
'''

for x in diccionario:
    if "M-40" in x: 
        valores = diccionario.get(x) # obtener el valor correspondiente para el identificador 
        fin = "" # declarar variable para mensaje en caso de que la incidencia tenga hora fin
        cleantext =  cleanhtml(valores[5]) # quitar las etiquetas de html del texto que describe la incidencia 
        if valores[2] != '':  # En caso de que exista una hora fin
            mensaje = "Hubo un atasco en la carretera " + valores[4]
            fin = " el cual terminó a las " + valores[2] + " el día " + valores[3]
        else: 
            mensaje = "Existe un atasco en la carretera " + valores[4]
        mensaje = mensaje + " que inicio a las " + valores[0] + " el día " + valores[1]
        mensaje = mensaje + fin
        mensaje = mensaje + " con la siguientes características:\n" +  cleantext

        print(mensaje+"\n")
# Out:
# Existe un atasco en la carretera M-40 que inicio a las 10:23 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  M-40   a la altura de MADRID (MADRID) desde el  km 32 al  km 28 sentido CRECIENTE DE LA KILOMETRACIÓN hacia A-6
#
# Existe un atasco en la carretera M-40 que inicio a las 09:28 el día 06/03/2019 con la siguientes características:
# RETENCIÓN / CONGESTIÓN por CIRCULACIÓN con circulación irregular  en:    - La AUTOPISTA / AUTOVÍA  M-40   a la altura de MADRID (MADRID) desde el  km 21 al  km 26 sentido DECRECIENTE DE LA KILOMETRACIÓN hacia A-4

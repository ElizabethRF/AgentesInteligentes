# %%
import urllib.request as ur
import re 

f = ur.urlopen('https://resultados.as.com/resultados/futbol/primera/jornada')
s = f.read().decode()

# %%
# Método para eliminar tags html que no nos interesan con ER 
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr,'',raw_html)
    return cleantext

# %%
from pprint import pprint     # import para hacer prints boninitos 

#Obtener url de cada jornada 
urlJornadas = re.findall('<li>.*?cont-jornada" href="(.*?)".*?</li>',s,re.DOTALL)

pprint(urlJornadas)
# Out:
# ['/resultados/futbol/primera/2018_2019/jornada/regular_a_1/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_2/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_3/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_4/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_5/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_6/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_7/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_8/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_9/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_10/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_11/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_12/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_13/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_14/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_15/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_16/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_17/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_18/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_19/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_20/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_21/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_22/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_23/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_24/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_25/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_26/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_27/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_28/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_29/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_30/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_31/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_32/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_33/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_34/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_35/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_36/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_37/',
#  '/resultados/futbol/primera/2018_2019/jornada/regular_a_38/']

# %%
import datetime

now = datetime.datetime.now()
months = ['Ago','Sep','Oct','Nov','Dic','Ene','Feb','Mar','Abr','May','Jun','Jul'] #Inicia en agosto como la temporada 
day = 4 # now.day
month = (now.month + 4) % 12



#f = ur.urlopen("https://resultados.as.com/resultados/futbol/primera/2018_2019/jornada/regular_a_1/")
#jornadai = f.read().decode()




    

# Para pasados 
def pasados():
    # Obtener Equipo1 GolesE1 GolesE2 Equipo2
    marcadorPasado = re.findall('class="nombre-equipo".*?>(.*?)</span>.*?class="resultado">.*?((..).-.(..)).*?</div>.*?class="nombre-equipo".*?>(.*?)</span>',jornadai,re.DOTALL)
    print("Resultados: ")
    for x in marcadorPasado:
        print(x[0] + x[1] +x[4])


    
# Para actuales 
# Obtener Equipo1 GolesE1 GolesE2 Equipo2 para los que lo tengan 
def actuales():
    listaResultados = jornadai.split('<li class="list-resultado">')
    listaResultados.pop(0)

    jugadosActual = []
    futurosActual = []

    for x in range(10):
        marcadorActual = []
        marcadorActual = re.findall('class="nombre-equipo".*?>(.*?)</span>.*?class="resultado">.*?((..).-.(..)).*?</div>.*?class="nombre-equipo".*?>(.*?)</span>',listaResultados[x],re.DOTALL)
        if marcadorActual[0][1] == '   -   ': 
            juegosFuturos = re.findall('class="nombre-equipo".*?>(.*?)</span>.*?class="nombre-equipo".*?>(.*?)</span>.*?<span class="fecha">(.*?)</span>',listaResultados[x],re.DOTALL)
            futurosActual.append(juegosFuturos[0])
        else:
            jugadosActual.append(marcadorActual[0])

    print("Resultados partidos jugados:")        
    for x in jugadosActual: 
        print(x[0] + x[1] +x[4])
    
    print("\nPartidos restantes:")
    for x in futurosActual:
        print(x[0] + " - " + x[1] + " en la fecha y horario " + x[2])



# para los que no lo tengan, obtener Equipo1 Equipo2 FechaDeJuego

# Para futuros
# obtener Equipo1 Equipo2 FechaDeJuego
def futuros():
    juegosFuturos = re.findall('class="nombre-equipo".*?>(.*?)</span>.*?class="nombre-equipo".*?>(.*?)</span>.*?<span class="fecha">(.*?)</span>',jornadai,re.DOTALL)
    print("Partidos pendientes:")
    for x in juegosFuturos:
        print(x[0] + " - " + x[1] + " en la fecha y horario " + x[2])

# %%
def printFuture(jornadaFecha): 
    if jornadaFecha[0][2] == '':
        if jornadaFecha[0][3] != '':
            print("La " + jornadaFecha[0][0] + " se realizará del " + jornadaFecha[0][1] + " al "+ jornadaFecha[0][3] +" de " + jornadaFecha[0][4] )
        else: 
            print("La " + jornadaFecha[0][0] + " se realizará el " + jornadaFecha[0][1] + " de " + jornadaFecha[0][4] )
            
    else: 
        if jornadaFecha[0][3] != '':
            print("La " + jornadaFecha[0][0] + " se realizará del " + jornadaFecha[0][1] + " de " + jornadaFecha[0][2]+ " al "+ jornadaFecha[0][3] +" de " + jornadaFecha[0][4] )
        else: 
            print("La " + jornadaFecha[0][0] + " se realizará el " + jornadaFecha[0][1] + " de " + jornadaFecha[0][4] )

def printPast(jornadaFecha):
    if jornadaFecha[0][2] == '':  
        if jornadaFecha[0][3] != '':
            print("La " + jornadaFecha[0][0] + " se realizó del " + jornadaFecha[0][1] + " al "+ jornadaFecha[0][3] + " de " + jornadaFecha[0][4] )
        else: 
             print("La " + jornadaFecha[0][0] + " se realizó el " + jornadaFecha[0][1] + " de " + jornadaFecha[0][4] )
    else:
        if jornadaFecha[0][3] != '':
            print("La " + jornadaFecha[0][0] + " se realizó del " + jornadaFecha[0][1] + " de " + jornadaFecha[0][2] + " al "+ jornadaFecha[0][3] + " de " + jornadaFecha[0][4] )
        else: 
             print("La " + jornadaFecha[0][0] + " se realizó el " + jornadaFecha[0][1] + " de " + jornadaFecha[0][4] )
        

def printCurrent(jornadaFecha):
    print("La " + jornadaFecha[0][0] + " se está realizando")
            
#Abrir la jornada correspondiente para cada url 
for x in urlJornadas:
    f = ur.urlopen("https://resultados.as.com"+x)
    jornadai = f.read().decode()
    #print(s + "\n")
    #Obtener número de jornada y fecha 
    jornadaFecha = re.findall('<h2 class="tit-modulo">.*?(Jornada \d*).*?>(\d\d) (.*?)* *-* *(\d\d)* *(...)<.*?</h2>',jornadai,re.DOTALL)
    

    if jornadaFecha[0][2] == '':  
        if months.index(jornadaFecha[0][4]) > month:
            printFuture(jornadaFecha)
            futuros()
        elif months.index(jornadaFecha[0][4]) < month:
            printPast(jornadaFecha)
            pasados()
        elif months.index(jornadaFecha[0][4]) == month:
            if int(jornadaFecha[0][1]) > day:
                printFuture(jornadaFecha)
                futuros()
            elif jornadaFecha[0][3] != '':
                if day <= int(jornadaFecha[0][3]) and  day >= int(jornadaFecha[0][1]):
                    printCurrent(jornadaFecha)
                    actuales()
                else: 
                    printPast(jornadaFecha)
                    pasados()
            elif int(jornadaFecha[0][1]) == day:
                printCurrent(jornadaFecha)
                actuales()
            else:
                printPast(jornadaFecha)
    else: 
        if months.index(jornadaFecha[0][2]) > month:
            printFuture(jornadaFecha)
            futuros()
        elif months.index(jornadaFecha[0][4]) < month:
            printPast(jornadaFecha)
            pasados()
        elif months.index(jornadaFecha[0][2]) < month: # estamos en mes 2 
            if jornadaFecha[0][3] < day:
                printPast(jornadaFecha)
                pasados()
            else:
                printCurrent(jornadaFecha)
                actuales() 
        else: # Estamos en mes 1 
            if jornadaFecha[0][1] > day:
                printFuture(jornadaFecha)
                futuros()
            else:
                printCurrent(jornadaFecha)
                actuales() 

        
    print("\n\n\n")
# Out:
# La Jornada 1 se realizó del 17 al 20 de Ago
# Resultados:
# Girona 0 - 0 Valladolid
# Betis 0 - 3 Levante
# Celta 1 - 1 Espanyol
# Villarreal 1 - 2 R. Sociedad
# Barcelona 3 - 0 Alavés
# Eibar 1 - 2 Huesca
# Rayo 1 - 4 Sevilla
# Real Madrid 2 - 0 Getafe
# Valencia 1 - 1 Atlético
# Athletic 2 - 1 Leganés
#
#
#
#
# La Jornada 2 se realizó del 24 al 27 de Ago
# Resultados:
# Getafe 2 - 0 Eibar
# Leganés 2 - 2 R. Sociedad
# Alavés 0 - 0 Betis
# Atlético 1 - 0 Rayo
# Valladolid 0 - 1 Barcelona
# Espanyol 2 - 0 Valencia
# Sevilla 0 - 0 Villarreal
# Girona 1 - 4 Real Madrid
# Levante 1 - 2 Celta
# Athletic 2 - 2 Huesca
#
#
#
#
# La Jornada 3 se realizó del 31 al 24 de Oct
# Resultados:
# Getafe 0 - 0 Valladolid
# Villarreal 0 - 1 Girona
# Eibar 2 - 1 R. Sociedad
# Celta 2 - 0 Atlético
# Real Madrid 4 - 1 Leganés
# Levante 2 - 2 Valencia
# Alavés 2 - 1 Espanyol
# Barcelona 8 - 2 Huesca
# Betis 1 - 0 Sevilla
# Rayo 1 - 1 Athletic
#
#
#
#
# La Jornada 4 se realizó del 14 al 17 de Sep
# Resultados:
# Huesca 0 - 1 Rayo
# Atlético 1 - 1 Eibar
# R. Sociedad 1 - 2 Barcelona
# Valencia 0 - 0 Betis
# Athletic 1 - 1 Real Madrid
# Leganés 0 - 1 Villarreal
# Espanyol 1 - 0 Levante
# Valladolid 0 - 1 Alavés
# Sevilla 0 - 2 Getafe
# Girona 3 - 2 Celta
#
#
#
#
# La Jornada 5 se realizó del 21 al 23 de Sep
# Resultados:
# Huesca 0 - 1 R. Sociedad
# Rayo 1 - 5 Alavés
# Eibar 1 - 0 Leganés
# Celta 3 - 3 Valladolid
# Getafe 0 - 2 Atlético
# Real Madrid 1 - 0 Espanyol
# Levante 2 - 6 Sevilla
# Villarreal 0 - 0 Valencia
# Betis 2 - 2 Athletic
# Barcelona 2 - 2 Girona
#
#
#
#
# La Jornada 6 se realizó del 25 al 27 de Sep
# Resultados:
# Espanyol 1 - 0 Eibar
# R. Sociedad 2 - 2 Rayo
# Atlético 3 - 0 Huesca
# Leganés 2 - 1 Barcelona
# Athletic 0 - 3 Villarreal
# Valencia 1 - 1 Celta
# Sevilla 3 - 0 Real Madrid
# Valladolid 2 - 1 Levante
# Alavés 1 - 1 Getafe
# Girona 0 - 1 Betis
#
#
#
#
# La Jornada 7 se realizó del 28 al 01 de Oct
# Resultados:
# Rayo 2 - 2 Espanyol
# R. Sociedad 0 - 1 Valencia
# Barcelona 1 - 1 Athletic
# Eibar 1 - 3 Sevilla
# Real Madrid 0 - 0 Atlético
# Huesca 1 - 1 Girona
# Villarreal 0 - 1 Valladolid
# Levante 2 - 1 Alavés
# Betis 1 - 0 Leganés
# Celta 1 - 1 Getafe
#
#
#
#
# La Jornada 8 se realizó del 05 al 07 de Oct
# Resultados:
# Athletic 1 - 3 R. Sociedad
# Girona 2 - 3 Eibar
# Getafe 0 - 1 Levante
# Alavés 1 - 0 Real Madrid
# Leganés 1 - 0 Rayo
# Valladolid 1 - 0 Huesca
# Atlético 1 - 0 Betis
# Sevilla 2 - 1 Celta
# Espanyol 3 - 1 Villarreal
# Valencia 1 - 1 Barcelona
#
#
#
#
# La Jornada 9 se realizó del 19 al 22 de Oct
# Resultados:
# Celta 0 - 1 Alavés
# Real Madrid 1 - 2 Levante
# Valencia 1 - 1 Leganés
# Villarreal 1 - 1 Atlético
# Barcelona 4 - 2 Sevilla
# Rayo 1 - 2 Getafe
# Eibar 1 - 1 Athletic
# Huesca 0 - 2 Espanyol
# Betis 0 - 1 Valladolid
# R. Sociedad 0 - 0 Girona
#
#
#
#
# La Jornada 10 se realizó del 26 al 28 de Oct
# Resultados:
# Valladolid 1 - 1 Espanyol
# Girona 2 - 1 Rayo
# Athletic 0 - 0 Valencia
# Levante 2 - 0 Leganés
# Celta 4 - 0 Eibar
# Atlético 2 - 0 R. Sociedad
# Getafe 2 - 0 Betis
# Barcelona 5 - 1 Real Madrid
# Alavés 2 - 1 Villarreal
# Sevilla 2 - 1 Huesca
#
#
#
#
# La Jornada 11 se realizó del 03 al 05 de Nov
# Resultados:
# Leganés 1 - 1 Atlético
# Real Madrid 2 - 0 Valladolid
# Valencia 0 - 1 Girona
# Rayo 2 - 3 Barcelona
# Eibar 2 - 1 Alavés
# Villarreal 1 - 1 Levante
# R. Sociedad 0 - 0 Sevilla
# Huesca 1 - 1 Getafe
# Betis 3 - 3 Celta
# Espanyol 1 - 0 Athletic
#
#
#
#
# La Jornada 12 se realizó del 09 al 11 de Nov
# Resultados:
# Levante 1 - 3 R. Sociedad
# Valladolid 0 - 0 Eibar
# Getafe 0 - 1 Valencia
# Atlético 3 - 2 Athletic
# Girona 0 - 0 Leganés
# Alavés 2 - 1 Huesca
# Barcelona 3 - 4 Betis
# Rayo 2 - 2 Villarreal
# Sevilla 2 - 1 Espanyol
# Celta 2 - 4 Real Madrid
#
#
#
#
# La Jornada 13 se realizó del 23 al 26 de Nov
# Resultados:
# Leganés 1 - 0 Alavés
# Eibar 3 - 0 Real Madrid
# Valencia 3 - 0 Rayo
# Huesca 2 - 2 Levante
# Atlético 1 - 1 Barcelona
# Athletic 1 - 1 Getafe
# Sevilla 1 - 0 Valladolid
# Espanyol 1 - 3 Girona
# Villarreal 2 - 1 Betis
# R. Sociedad 2 - 1 Celta
#
#
#
#
# La Jornada 14 se realizó del 30 al 03 de Dic
# Resultados:
# Rayo 1 - 0 Eibar
# Celta 2 - 0 Huesca
# Valladolid 2 - 4 Leganés
# Getafe 3 - 0 Espanyol
# Real Madrid 2 - 0 Valencia
# Betis 1 - 0 R. Sociedad
# Girona 1 - 1 Atlético
# Barcelona 2 - 0 Villarreal
# Alavés 1 - 1 Sevilla
# Levante 3 - 0 Athletic
#
#
#
#
# La Jornada 15 se realizó del 07 al 10 de Dic
# Resultados:
# Leganés 1 - 1 Getafe
# Atlético 3 - 0 Alavés
# Valencia 1 - 1 Sevilla
# Villarreal 2 - 3 Celta
# Espanyol 0 - 4 Barcelona
# Eibar 4 - 4 Levante
# Huesca 0 - 1 Real Madrid
# R. Sociedad 1 - 2 Valladolid
# Betis 2 - 0 Rayo
# Athletic 1 - 0 Girona
#
#
#
#
# La Jornada 16 se realizó del 14 al 17 de Dic
# Resultados:
# Celta 0 - 0 Leganés
# Getafe 1 - 0 R. Sociedad
# Valladolid 2 - 3 Atlético
# Real Madrid 1 - 0 Rayo
# Eibar 1 - 1 Valencia
# Sevilla 2 - 0 Girona
# Espanyol 1 - 3 Betis
# Huesca 2 - 2 Villarreal
# Levante 0 - 5 Barcelona
# Alavés 0 - 0 Athletic
#
#
#
#
# La Jornada 17 se realizó del 21 al 03 de Ene
# Resultados:
# Girona 1 - 1 Getafe
# R. Sociedad 0 - 1 Alavés
# Betis 1 - 1 Eibar
# Atlético 1 - 0 Espanyol
# Barcelona 2 - 0 Celta
# Athletic 1 - 1 Valladolid
# Valencia 2 - 1 Huesca
# Leganés 1 - 1 Sevilla
# Rayo 2 - 1 Levante
# Villarreal 2 - 2 Real Madrid
#
#
#
#
# La Jornada 18 se realizó del 04 al 07 de Ene
# Resultados:
# Levante 2 - 2 Girona
# Espanyol 1 - 0 Leganés
# Valladolid 0 - 1 Rayo
# Alavés 2 - 1 Valencia
# Huesca 2 - 1 Betis
# Eibar 0 - 0 Villarreal
# Sevilla 1 - 1 Atlético
# Real Madrid 0 - 2 R. Sociedad
# Getafe 1 - 2 Barcelona
# Celta 1 - 2 Athletic
#
#
#
#
# La Jornada 19 se realizó del 11 al 14 de Ene
# Resultados:
# Rayo 4 - 2 Celta
# Leganés 1 - 0 Huesca
# Valencia 1 - 1 Valladolid
# Girona 1 - 1 Alavés
# Villarreal 1 - 2 Getafe
# Atlético 1 - 0 Levante
# Athletic 2 - 0 Sevilla
# Barcelona 3 - 0 Eibar
# Betis 1 - 2 Real Madrid
# R. Sociedad 3 - 2 Espanyol
#
#
#
#
# La Jornada 20 se realizó del 18 al 21 de Ene
# Resultados:
# Getafe 4 - 0 Alavés
# Real Madrid 2 - 0 Sevilla
# Huesca 0 - 3 Atlético
# Celta 1 - 2 Valencia
# Betis 3 - 2 Girona
# Villarreal 1 - 1 Athletic
# Rayo 2 - 2 R. Sociedad
# Levante 2 - 0 Valladolid
# Barcelona 3 - 1 Leganés
# Eibar 3 - 0 Espanyol
#
#
#
#
# La Jornada 21 se realizó del 26 al 28 de Ene
# Resultados:
# Sevilla 5 - 0 Levante
# Atlético 2 - 0 Getafe
# Leganés 2 - 2 Eibar
# Valencia 3 - 0 Villarreal
# Valladolid 2 - 1 Celta
# Girona 0 - 2 Barcelona
# R. Sociedad 0 - 0 Huesca
# Athletic 1 - 0 Betis
# Espanyol 2 - 4 Real Madrid
# Alavés 0 - 1 Rayo
#
#
#
#
# La Jornada 22 se realizó del 01 al 04 de Feb
# Resultados:
# Huesca 4 - 0 Valladolid
# Levante 0 - 0 Getafe
# R. Sociedad 2 - 1 Athletic
# Barcelona 2 - 2 Valencia
# Celta 1 - 0 Sevilla
# Villarreal 2 - 2 Espanyol
# Betis 1 - 0 Atlético
# Eibar 3 - 0 Girona
# Real Madrid 3 - 0 Alavés
# Rayo 1 - 2 Leganés
#
#
#
#
# La Jornada 23 se realizó del 08 al 11 de Feb
# Resultados:
# Valladolid 0 - 0 Villarreal
# Getafe 3 - 1 Celta
# Atlético 1 - 3 Real Madrid
# Espanyol 2 - 1 Rayo
# Girona 0 - 2 Huesca
# Leganés 3 - 0 Betis
# Valencia 0 - 0 R. Sociedad
# Sevilla 2 - 2 Eibar
# Athletic 0 - 0 Barcelona
# Alavés 2 - 0 Levante
#
#
#
#
# La Jornada 24 se realizó del 15 al 18 de Feb
# Resultados:
# Eibar 2 - 2 Getafe
# Celta 1 - 4 Levante
# Rayo 0 - 1 Atlético
# R. Sociedad 3 - 0 Leganés
# Barcelona 1 - 0 Valladolid
# Real Madrid 1 - 2 Girona
# Valencia 0 - 0 Espanyol
# Villarreal 3 - 0 Sevilla
# Betis 1 - 1 Alavés
# Huesca 0 - 1 Athletic
#
#
#
#
# La Jornada 25 se realizó del 22 al 25 de Feb
# Resultados:
# Espanyol 1 - 1 Huesca
# Getafe 2 - 1 Rayo
# Sevilla 2 - 4 Barcelona
# Alavés 0 - 0 Celta
# Athletic 1 - 0 Eibar
# Leganés 1 - 1 Valencia
# Atlético 2 - 0 Villarreal
# Valladolid 0 - 2 Betis
# Levante 1 - 2 Real Madrid
# Girona 0 - 0 R. Sociedad
#
#
#
#
# La Jornada 26 se está realizando
# Resultados partidos jugados:
# Rayo 0 - 2 Girona
# Espanyol 3 - 1 Valladolid
# Villarreal 1 - 2 Alavés
# Huesca 2 - 1 Sevilla
# Real Madrid 0 - 1 Barcelona
# Eibar 1 - 0 Celta
# Betis 1 - 2 Getafe
# R. Sociedad 0 - 2 Atlético
# Valencia 2 - 0 Athletic
# Leganés 1 - 0 Levante
#
# Partidos restantes:
#
#
#
#
# La Jornada 27 se realizará del 08 al 10 de Mar
# Partidos pendientes:
# Athletic - Espanyol en la fecha y horario V-08/03 21:00
# Alavés - Eibar en la fecha y horario S-09/03 13:00
# Atlético - Leganés en la fecha y horario S-09/03 16:15
# Barcelona - Rayo en la fecha y horario S-09/03 18:30
# Getafe - Huesca en la fecha y horario S-09/03 20:45
# Celta - Betis en la fecha y horario D-10/03 12:00
# Girona - Valencia en la fecha y horario D-10/03 16:15
# Levante - Villarreal en la fecha y horario D-10/03 18:30
# Sevilla - R. Sociedad en la fecha y horario D-10/03 18:30
# Valladolid - Real Madrid en la fecha y horario D-10/03 20:45
#
#
#
#
# La Jornada 28 se realizará del 15 al 17 de Mar
# Partidos pendientes:
# R. Sociedad - Levante en la fecha y horario V-15/03 21:00
# Huesca - Alavés en la fecha y horario S-16/03 13:00
# Real Madrid - Celta en la fecha y horario S-16/03 16:15
# Athletic - Atlético en la fecha y horario S-16/03 18:30
# Leganés - Girona en la fecha y horario S-16/03 20:45
# Eibar - Valladolid en la fecha y horario D-17/03 12:00
# Espanyol - Sevilla en la fecha y horario D-17/03 16:15
# Valencia - Getafe en la fecha y horario D-17/03 18:30
# Villarreal - Rayo en la fecha y horario D-17/03 18:30
# Betis - Barcelona en la fecha y horario D-17/03 20:45
# La Jornada 29 se realizará del 29 al 31 de Mar
# Partidos pendientes:
# Girona - Athletic en la fecha y horario V-29/03 21:00
# Getafe - Leganés en la fecha y horario S-30/03 13:00
# Barcelona - Espanyol en la fecha y horario S-30/03 16:15
# Celta - Villarreal en la fecha y horario S-30/03 18:30
# Alavés - Atlético en la fecha y horario S-30/03 20:45
# Levante - Eibar en la fecha y horario D-31/03 12:00
# Rayo - Betis en la fecha y horario D-31/03 14:00
# Sevilla - Valencia en la fecha y horario D-31/03 16:15
# Real Madrid - Huesca en la fecha y horario D-31/03 18:30
# Valladolid - R. Sociedad en la fecha y horario D-31/03 20:45
#
#
#
#
# La Jornada 30 se realizará el 03 de Abr
# Partidos pendientes:
# Sevilla - Alavés en la fecha y horario X-03/04 18:30
# Valencia - Real Madrid en la fecha y horario X-03/04 18:30
# Villarreal - Barcelona en la fecha y horario X-03/04 18:30
# R. Sociedad - Betis en la fecha y horario X-03/04 18:30
# Leganés - Valladolid en la fecha y horario X-03/04 18:30
# Athletic - Levante en la fecha y horario X-03/04 18:30
# Eibar - Rayo en la fecha y horario X-03/04 18:30
# Atlético - Girona en la fecha y horario X-03/04 18:30
# Espanyol - Getafe en la fecha y horario X-03/04 18:30
# Huesca - Celta en la fecha y horario X-03/04 18:30
#
#
#
#
# La Jornada 31 se realizará del 06 al 07 de Abr
# Partidos pendientes:
# Girona - Espanyol en la fecha y horario S-06/04 13:00
# Real Madrid - Eibar en la fecha y horario S-06/04 16:15
# Rayo - Valencia en la fecha y horario S-06/04 18:30
# Barcelona - Atlético en la fecha y horario S-06/04 20:45
# Alavés - Leganés en la fecha y horario D-07/04 12:00
# Getafe - Athletic en la fecha y horario D-07/04 14:00
# Valladolid - Sevilla en la fecha y horario D-07/04 16:15
# Levante - Huesca en la fecha y horario D-07/04 18:30
# Celta - R. Sociedad en la fecha y horario D-07/04 18:30
# Betis - Villarreal en la fecha y horario D-07/04 20:45
#
#
#
#
# La Jornada 32 se realizará el 14 de Abr
# Partidos pendientes:
# R. Sociedad - Eibar en la fecha y horario D-14/04 18:30
# Valladolid - Getafe en la fecha y horario D-14/04 18:30
# Leganés - Real Madrid en la fecha y horario D-14/04 18:30
# Valencia - Levante en la fecha y horario D-14/04 18:30
# Sevilla - Betis en la fecha y horario D-14/04 18:30
# Athletic - Rayo en la fecha y horario D-14/04 18:30
# Huesca - Barcelona en la fecha y horario D-14/04 18:30
# Espanyol - Alavés en la fecha y horario D-14/04 18:30
# Atlético - Celta en la fecha y horario D-14/04 18:30
# Girona - Villarreal en la fecha y horario D-14/04 18:30
#
#
#
#
# La Jornada 33 se realizará el 21 de Abr
# Partidos pendientes:
# Rayo - Huesca en la fecha y horario D-21/04 18:30
# Betis - Valencia en la fecha y horario D-21/04 18:30
# Real Madrid - Athletic en la fecha y horario D-21/04 18:30
# Villarreal - Leganés en la fecha y horario D-21/04 18:30
# Levante - Espanyol en la fecha y horario D-21/04 18:30
# Getafe - Sevilla en la fecha y horario D-21/04 18:30
# Barcelona - R. Sociedad en la fecha y horario D-21/04 18:30
# Alavés - Valladolid en la fecha y horario D-21/04 18:30
# Celta - Girona en la fecha y horario D-21/04 18:30
# Eibar - Atlético en la fecha y horario D-21/04 18:30
#
#
#
#
# La Jornada 34 se realizará el 24 de Abr
# Partidos pendientes:
# R. Sociedad - Villarreal en la fecha y horario X-24/04 18:30
# Levante - Betis en la fecha y horario X-24/04 18:30
# Valladolid - Girona en la fecha y horario X-24/04 18:30
# Sevilla - Rayo en la fecha y horario X-24/04 18:30
# Leganés - Athletic en la fecha y horario X-24/04 18:30
# Espanyol - Celta en la fecha y horario X-24/04 18:30
# Alavés - Barcelona en la fecha y horario X-24/04 18:30
# Atlético - Valencia en la fecha y horario X-24/04 18:30
# Huesca - Eibar en la fecha y horario X-24/04 18:30
# Getafe - Real Madrid en la fecha y horario X-24/04 18:30
#
#
#
#
# La Jornada 35 se realizará el 28 de Abr
# Partidos pendientes:
# Betis - Espanyol en la fecha y horario D-28/04 18:30
# R. Sociedad - Getafe en la fecha y horario D-28/04 18:30
# Villarreal - Huesca en la fecha y horario D-28/04 18:30
# Rayo - Real Madrid en la fecha y horario D-28/04 18:30
# Valencia - Eibar en la fecha y horario D-28/04 18:30
# Leganés - Celta en la fecha y horario D-28/04 18:30
# Athletic - Alavés en la fecha y horario D-28/04 18:30
# Barcelona - Levante en la fecha y horario D-28/04 18:30
# Atlético - Valladolid en la fecha y horario D-28/04 18:30
# Girona - Sevilla en la fecha y horario D-28/04 18:30
#
#
#
#
# La Jornada 36 se realizará el 05 de May
# Partidos pendientes:
# Levante - Rayo en la fecha y horario D-05/05 18:30
# Valladolid - Athletic en la fecha y horario D-05/05 18:30
# Sevilla - Leganés en la fecha y horario D-05/05 18:30
# Huesca - Valencia en la fecha y horario D-05/05 18:30
# Real Madrid - Villarreal en la fecha y horario D-05/05 18:30
# Getafe - Girona en la fecha y horario D-05/05 18:30
# Celta - Barcelona en la fecha y horario D-05/05 18:30
# Alavés - R. Sociedad en la fecha y horario D-05/05 18:30
# Espanyol - Atlético en la fecha y horario D-05/05 18:30
# Eibar - Betis en la fecha y horario D-05/05 18:30
#
#
#
#
# La Jornada 37 se realizará el 12 de May
# Partidos pendientes:
# Betis - Huesca en la fecha y horario D-12/05 18:30
# Villarreal - Eibar en la fecha y horario D-12/05 18:30
# Rayo - Valladolid en la fecha y horario D-12/05 18:30
# Valencia - Alavés en la fecha y horario D-12/05 18:30
# R. Sociedad - Real Madrid en la fecha y horario D-12/05 18:30
# Leganés - Espanyol en la fecha y horario D-12/05 18:30
# Atlético - Sevilla en la fecha y horario D-12/05 18:30
# Athletic - Celta en la fecha y horario D-12/05 18:30
# Girona - Levante en la fecha y horario D-12/05 18:30
# Barcelona - Getafe en la fecha y horario D-12/05 18:30
#
#
#
#
# La Jornada 38 se realizará el 19 de May
# Partidos pendientes:
# Levante - Atlético en la fecha y horario D-19/05 18:30
# Real Madrid - Betis en la fecha y horario D-19/05 18:30
# Valladolid - Valencia en la fecha y horario D-19/05 18:30
# Huesca - Leganés en la fecha y horario D-19/05 18:30
# Sevilla - Athletic en la fecha y horario D-19/05 18:30
# Eibar - Barcelona en la fecha y horario D-19/05 18:30
# Alavés - Girona en la fecha y horario D-19/05 18:30
# Celta - Rayo en la fecha y horario D-19/05 18:30
# Espanyol - R. Sociedad en la fecha y horario D-19/05 18:30
# Getafe - Villarreal en la fecha y horario D-19/05 18:30
